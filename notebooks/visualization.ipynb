# %% [markdown]
# ## Visualization for the Cleaned Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#reading the cleaned imdb file from the data folder

df=pd.read_csv('../data/imdb-cleaned.csv')
df
# Out:
#                          Name  Year  Duration  Genres  IMDB  \
# 0    The Shawshank Redemption  1994       142   Drama   9.3
# 1               The Godfather  1972       175   Crime   9.2
# 2             The Dark Knight  2008       152  Action   9.0
# 3      The Godfather: Part II  1974       202   Crime   9.0
# 4                12 Angry Men  1957        96   Crime   9.0
# ..                        ...   ...       ...     ...   ...
# 995    Breakfast at Tiffany's  1961       115  Comedy   7.6
# 996                     Giant  1956       201   Drama   7.6
# 997     From Here to Eternity  1953       118   Drama   7.6
# 998                  Lifeboat  1944        97   Drama   7.6
# 999              The 39 Steps  1935        86   Crime   7.6
#
#                  Director               Lead  Votes_per_K  Gross_per_M  \
# 0          Frank Darabont        Tim Robbins     2343.110        28.34
# 1    Francis Ford Coppola      Marlon Brando     1620.367       134.97
# ...

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### IMDB Rating Histogram
#
# - The graph is the **Right Skewed Graph** as the IMDB rating increases the number of the films get decreases
# - Rating of **7 to 7.9** contain the maximum number of the movies.
# - **KEY INSIGHTS :** HIGh IMDB rating contain less number of movies

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='IMDB',color='violet')
plt.title('IMDB Ratings Analysis')
plt.xlabel('IMDB Ratings')
plt.ylabel('Total Number of Films')
plt.grid()
plt.show()

# %%
#KDE Plot for the same analysis

plt.figure(figsize=(10,6))
sns.kdeplot(data=df,x='IMDB',color='green',linewidth=2.5)
plt.title('IMDB Ratings Analysis')
plt.xlabel('IMDB Ratings')
plt.ylabel('Total Number of Films')
plt.grid()
plt.show()

# %% [markdown]
# ### Gross Per Million Analysis
#
# - The graph is the **RIGHT SKEWED GRAPH** only few number of films had earned more than 800M $
#
# - 400+ films have earned less than 100M $
# - Only 2 to 3 films have earned more than 800M+ $

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Gross_per_M',color='violet')

plt.xlabel('Gross Per Million')
plt.ylabel('Total Number of Films')

plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(data=df,x='Gross_per_M',color='green',linewidth=3)

plt.xlabel('Gross Per Million')
plt.ylabel('Total Number of Films')

plt.grid()
plt.show()

# %% [markdown]
# ### Duration Analysis
#
# - Average Duration of the film is around **90 to 120 minutes**
# - the graph is the **RIGHT SKEWED GRAPH** the number of film decreases as the duration increases
# - ONLY 1 to 2 films have duration higher than 300+ or less than 50 minutes
#
# - **KEY INSIGHTS :** HIGH DURATION contains LOW NUMBER OF FILMS

# %%
plt.figure(figsize=(10,6))

sns.histplot(data=df,x='Duration',color='violet')
plt.xlabel('Total Durations')
plt.ylabel('Number of Films')
plt.title('Duartion Analysis')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.kdeplot(data=df,x='Duration',color='green',linewidth=3)
plt.xlabel('Total Durations')
plt.ylabel('Number of Films')
plt.title('Duartion Analysis')
plt.grid()
plt.show()

# %% [markdown]
# ### Metascore Analysis
#
# - The Graph is the **LEFT SKEWED GRAPH** only few films contain the less number of metascore
# - More than 200+ films have metascore of 79
# - Less than 50 films have metascore of 100

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Metascore',color='violet')

plt.xlabel('Metascore of Movies')
plt.ylabel('Number of Films')
plt.title('Metascore Analysis')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(data=df,x='Metascore',color='green',linewidth=3)

plt.xlabel('Metascore of Movies')
plt.ylabel('Number of Films')
plt.title('Metascore Analysis')
plt.grid()
plt.show()

# %% [markdown]
# ### Genre Frequency
#
# - **DRAMA** is the most popular genre of all time total 289+ movies
# - Less favourites are **Fantasy and Thriller** less than 5 movies

# %%
plt.figure(figsize=(10,6))
#here we need to calculate the total number of genre

temp=df.groupby('Genres')['Name'].count().sort_values(ascending=False)
sns.barplot(x=temp.index,y=temp.values,hue=temp.index)
plt.xlabel('Genres')
plt.ylabel('Number of Films')
plt.title('Genres Frequency Analysis')
plt.xticks(rotation=45)

plt.grid()
plt.show()

# %% [markdown]
# ### Decade Analysis
#
# - the number of film increases as the Decade increases
# - **2010** have the highest number of the films
# - **1920** have the lowest number of the films
# - **2020** is currently evaluating and in progress

# %%
plt.figure(figsize=(10,6))
#here we need to calculate the total number of genre

dec=df.groupby('Decade')['Name'].count().sort_values(ascending=False)
sns.barplot(x=dec.index,y=dec.values,hue=dec.index,palette='deep')
plt.xlabel('Decades')
plt.ylabel('Number of Films')
plt.title('Decade Frequency Analysis')


plt.grid()
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### IMDB VS GROSS Analysis
#
# - **Negative Correlation** as the IMDB Rating increases the Earning of the film decreases
# - The film less than IMDB of **7 to 8.3** have earned more than 800M+
# - The highest rated film have less than 50M earning

# %%
plt.figure(figsize=(10,6))

sns.regplot(data=df,x='IMDB',y='Gross_per_M',scatter_kws={'color':'darkblue','s':50,'alpha':0.4},line_kws={'color':'red','linewidth':3})
plt.xlabel('IMDB Ratings')
plt.ylabel('Gross Per Million')
plt.title('IMDB vs Gross Analysis')
plt.grid()
plt.show()

# %% [markdown]
# ### IMDB VS Metascore Analysis
#
# - This graph is used to show the **Positive Correlation**
# - Film with the HIGH IMDB Rating have HIGH Metascore
# - There are also some films which have high IMDB rating but Metascore is low

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=df,x='IMDB',y='Metascore',
            scatter_kws={'color':'green','s':50,'alpha':0.4},
            line_kws={'color':'red','linewidth':3}
        )

plt.xlabel('IMDB Ratings')
plt.ylabel('Metascore')
plt.title('IMDB VS Metascore Analysis')
plt.grid()
plt.show()

# %% [markdown]
# ### IMDB VS Duration
#
# - There are less number of films whose **IMDB Rating** is 8.75 to 9.5 and there duration is less
# - the highest number of films have duration of about **60 to 120 hours**
# - One film with IMDB=8.1 have highest duration of more than 300+ minutes

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='IMDB',y='Duration',color='black',alpha=0.6,s=90)
plt.xlabel('IMDB Rating')
plt.ylabel('Film Duration')
plt.title('IMDB VS Duration Analysis')
plt.grid()
plt.show()

# %% [markdown]
# ### Votes Per K Vs Gross Per M
#
# - In the given graph the film which have lower votes have high earning
# - The film which have most number of votes have low earning then other films
# - Many film with about **100 votes** have **800M+ $ earning**

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='Votes_per_K',y='Gross_per_M',s=90,color='blue',alpha=0.6)
plt.xlabel('Votes Per K')
plt.ylabel('Gross Per M')
plt.title('Votes Vs Gross Analysis')
plt.grid()
plt.show()

# %% [markdown]
# ### Genre Vs Avg IMDB
#
# - The average IMDB Rating of the **Western** genre is higher then other Genres
# - The lowest average Imdb Rating are **Family and Thriller**
# - **Drama** which is more popular have average IMDB Rating of **7.8**

# %%
plt.figure(figsize=(10,6))
#but here we need to find on the basis of the avg IMDB

imdb=df.groupby('Genres')['IMDB'].mean().sort_values(ascending=False)
sns.barplot(x=imdb.index,y=imdb.values,hue=imdb.index,palette='summer')
plt.xlabel('Genres')
plt.ylabel('Average IMDB Rating')
plt.title('Genre Vs Average IMDB Rating')
plt.xticks(rotation=45)
plt.ylim(7.5,8.5)
plt.grid()
plt.show()

# %% [markdown]
# ### Genre Vs Average Gross
#
# - **Fantasy** is the genre which have more Average earning then any other Genre
# - **Western** genre have the highest average IMDB Ratings but in earning it is the lowest
#
# - **Drama** which is the most favourite genre have IMDB Rating of **120**

# %%
plt.figure(figsize=(10,6))
gross=df.groupby('Genres')['Gross_per_M'].mean().sort_values(ascending=False)
sns.barplot(x=gross.index,y=gross.values,hue=gross.index,palette='spring')
plt.xlabel('Genres')
plt.ylabel('Average Gross Per Million')
plt.xticks(rotation=45)
plt.title('Genre vs Average Gross Per Million')
plt.grid()
plt.show()

# %% [markdown]
# ### Decade Vs Average IMDB Combo Chart
#
# - In the given graph the IMDB Rating of **1920** is greater
# - **2020** contain only 6 number of movies
# - **1920** have total 11 number of films instead they have high IMDB Rating because they are the absolute best
# - **Fewer films= Highest average= Survivorship bias**

# %%
plt.figure(figsize=(10,6))
imdb_dec=df.groupby('Decade')['IMDB'].mean().sort_values(ascending=False)
sns.barplot(x=imdb_dec.index,y=imdb_dec.values,hue=imdb_dec.index,palette='magma')
plt.plot(range(len(imdb_dec)),imdb_dec.values,color='red',linewidth=3,marker='o')
plt.xlabel('Decade')
plt.ylabel('Average IMDB Ratings')
plt.title('Decade Vs Average IMDB Ratings')
plt.ylim(7.8,8.5)
plt.grid()
plt.show()

# %% [markdown]
# ### Decade vs Average Gross
#
# - **2020** have the highest earning but it contain only the **6** number of films so the analysis is somehow incomplete
# - **1920** having the highest IMDB rating have best metascore but earning is less than 100M

# %%
plt.figure(figsize=(10,6))
dec_gross=df.groupby('Decade')['Gross_per_M'].mean().sort_index(ascending=False)
sns.barplot(x=dec_gross.index,y=dec_gross.values,palette='viridis',hue=dec_gross.index,order=dec_gross.index,hue_order=dec_gross.index)
plt.plot(range(len(dec_gross)),dec_gross.values,color='blue',linewidth=3,marker='o')
plt.xlabel('Decades')
plt.ylabel('Average Gross Per Million')
plt.title('Decade Vs Average Gross Per Million')

plt.grid()
plt.show()

# %% [markdown]
# ## Top Lists

# %% [markdown]
# ### TOP 10 Directors with Film Count

# %%
dir=df.groupby('Director')['Name'].count().sort_values(ascending=False).head(10)
sns.barplot(x=dir.values,y=dir.index,palette='spring')
plt.xlabel('Total Movies')
plt.ylabel('Director of Movie')
plt.title('Top 10 Director with Film Counts')
plt.xlim(6,15)
plt.grid()
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_7984\4277954927.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dir.values,y=dir.index,palette='spring')

# %% [markdown]
# ### TOP 10 Directors by Average Rating

# %%
dir_imdb=df.groupby('Director')['IMDB'].mean().sort_values(ascending=False).head(10)
sns.barplot(x=dir_imdb.values,y=dir_imdb.index,palette='magma')
plt.xlabel('Average IMDB Ratings')
plt.ylabel('Name of Directors')
plt.title('TOP 10 Directors by Average Rating')
plt.xlim(8.4,9)
plt.grid()
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_7984\2984467845.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dir_imdb.values,y=dir_imdb.index,palette='magma')

# %% [markdown]
# ### TOP 10 Lead Stars by Film Count

# %%
lead=df.groupby('Lead')['Name'].count().sort_values(ascending=False).head(10)
sns.barplot(x=lead.values,y=lead.index,palette='summer')
plt.xlabel('Number of Films')
plt.ylabel('Lead Actor')
plt.title('TOP 10 Lead Stars by Film Count')
plt.xlim(4,13)

plt.grid()
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_7984\3982951711.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=lead.values,y=lead.index,palette='summer')
